# %%
import pandas as pd

# %%
df_escuelas = pd.read_csv('escuelas.csv')
df_escuelas.head()
# Out:
#                                               Nombre    Latitud   Longitud
# 0            Escuela Primaria Laura Méndez de Cuenca  21.042841 -89.644951
# 1                             Escuela Primaria Zamná  21.037062 -89.625579
# 2  Escuela Primaria Ana Sofía Baeza García vesper...  20.996205 -89.708710

# %%
tamaño = len(df_escuelas)
i=1
tamaño
# Out:
# 3

# %%
jsfile = ""
jsfile = "var escuela = { 'type':'FeatureCollection', \n"
jsfile = jsfile + "'features': [ \n"

for index, row in df_escuelas.iterrows():
  nombre = row['Nombre']
  longitud = row['Longitud']
  latitud = row['Latitud']
  if i<tamaño:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}},\n"
    i+=1
  else:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}} \n]}; \n"

# %%
print(jsfile)
# Out:
# var escuela = { 'type':'FeatureCollection',
# 'features': [
#  {'type':'Feature',
#  'properties':{'nombre':'Escuela Primaria Laura Méndez de Cuenca'},
#  'geometry': {'type':'Point', 'coordinates':[-89.6449511,21.0428409]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Escuela Primaria Zamná'},
#  'geometry': {'type':'Point', 'coordinates':[-89.6255788,21.0370622]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Escuela Primaria Ana Sofía Baeza García vespertino'},
#  'geometry': {'type':'Point', 'coordinates':[-89.7087103,20.996205]}}
# ]};

# %%
with open('escuelas.js', 'a') as archivo:
  archivo.write(jsfile)
archivo.close()

# %%
df_direcciones = pd.read_csv('direcciones.csv')

# %%
df_direcciones.head()
# Out:
#    Unnamed: 0       resp1       resp2    latitud   longitud  \
# 0           0    'El día'  'Silencio'  19.446448 -99.082700
# 1           1  'La noche'     'Ruido'  19.402874 -99.193342
# 2           2    'El día'  'Silencio'  19.429304 -99.174960
# 3           3    'El día'     'Ruido'  19.430061 -99.114791
# 4           4  'La noche'     'Ruido'  19.432602 -99.133205
#
#                coordenadas                                          ubicacion  \
# 0  19.4464479, -99.0827003  Deportivo Oceanía, Avenida Oceanía, Colonia Sa...
# 1  19.4028736, -99.1933423  Calle Colibrí, Colonia Sears Roebuck, Álvaro O...
# 2  19.4293039, -99.1749605  Calle Darwin, Colonia Nueva Anzures, Miguel Hi...
# 3  19.4300609, -99.1147913  CETRAM San Lázaro, Calzada General Ignacio Zar...
# 4  19.4326018, -99.1332049  Zócalo de la Ciudad de México, Plaza de la Con...
#
#                                            Direccion
# 0  Deportivo Oceanía, Avenida Oceanía, Colonia Sa...
# 1  Calle Colibrí, Colonia Sears Roebuck, Álvaro O...
# 2  Calle Darwin, Colonia Nueva Anzures, Miguel Hi...
# 3  CETRAM San Lázaro, Calzada General Ignacio Zar...
# 4  Zócalo de la Ciudad de México, Plaza de la Con...

# %%
len(df_direcciones)
# Out:
# 10

# %%
df_dia = df_direcciones[(df_direcciones.resp1=="'El día'")]
df_dia
# Out:
#    Unnamed: 0     resp1       resp2    latitud   longitud  \
# 0           0  'El día'  'Silencio'  19.446448 -99.082700
# 2           2  'El día'  'Silencio'  19.429304 -99.174960
# 3           3  'El día'     'Ruido'  19.430061 -99.114791
# 5           5  'El día'  'Silencio'  19.419481 -99.192031
# 6           6  'El día'  'Silencio'  19.322801 -99.189175
# 8           8  'El día'  'Silencio'  19.405940 -99.100414
#
#                coordenadas                                          ubicacion  \
# 0  19.4464479, -99.0827003  Deportivo Oceanía, Avenida Oceanía, Colonia Sa...
# 2  19.4293039, -99.1749605  Calle Darwin, Colonia Nueva Anzures, Miguel Hi...
# 3  19.4300609, -99.1147913  CETRAM San Lázaro, Calzada General Ignacio Zar...
# 5  19.4194815, -99.1920307  Centro de Adiestramiento del C.G.P., Calzada M...
# 6  19.3228012, -99.1891748  Universidad Nacional Autónoma de México, Calle...
# 8  19.4059402, -99.1004137  Palacio de los Deportes, Viaducto Río de la Pi...
#
#                                            Direccion
# 0  Deportivo Oceanía, Avenida Oceanía, Colonia Sa...
# 2  Calle Darwin, Colonia Nueva Anzures, Miguel Hi...
# 3  CETRAM San Lázaro, Calzada General Ignacio Zar...
# 5  Centro de Adiestramiento del C.G.P., Calzada M...
# 6  Universidad Nacional Autónoma de México, Calle...
# 8  Palacio de los Deportes, Viaducto Río de la Pi...

# %%
tamaño = len(df_dia)
i=1
tamaño
# Out:
# 6

# %%
jsfile = ""
jsfile = "var dia = { 'type':'FeatureCollection', \n"
jsfile = jsfile + "'features': [ \n"

for index, row in df_dia.iterrows():
  respuesta = row['resp1']
  longitud = row['longitud']
  latitud = row['latitud']
  if i<tamaño:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'respuesta':'"+respuesta+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}},\n"
    i+=1
  else:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'respuesta':'"+respuesta+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}} \n]};\n"

# %%
print(jsfile)

# %%
with open('escuelas.js', 'a') as archivo:
  archivo.write(jsfile)
archivo.close()
